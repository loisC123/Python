# %%
import warnings # 警告模組
warnings.filterwarnings('ignore')

import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time
import random

cat = 'all' 
# cat = 'all'： 全部
# cat = 'BKA'： 圖書
# cat = 'EBA'： 電子書
# cat = 'AVA'： 影音
# cat = 'DPA'： 百貨
# cat = 'MGA'： 雜誌
# cat = 'all/ovs/1'： 海外專館

url_main = "http://search.books.com.tw/search/query/key/%s/cat/%s"

url_page = "https://search.books.com.tw/search/query/cat/%s/sort/1/v/0/ms2/ms2_1/page/%s/key/%s"



headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36',
          }

def web_crawler(item_name, total_pages, books, prices):
    
    for page in range(1, total_pages + 1):
    
        url = url_page % (cat, str(page), item_name)
        
        flag = True
        
        # 寫 while 的原因是連線會常常失敗(博客來網站伺服器拒絕 client 端連線)，
        # 所以重新嘗試連線，直到成功連線下載到資料為止
        while(flag):
            
            res = requests.get(url, headers = headers)  # 加上 headers = headers
    
            print("\n第%02d頁的網頁內容大小 = %d 位元組" % (page, len(res.text)))  # 可取得網頁內容大小
        
            if len(res.text) > 0:
                
                flag = False
                
            else:
                
                print('** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **')
                time.sleep(random.uniform(50, 60))

        #print(res.text)   # 使用 text 屬性將取得網頁的原始碼呈現出來
    
        soup = BeautifulSoup(res.text, 'html.parser')   # 將 html格式的字串傳進 BeautifulSoup
        
        items = soup.find_all('tbody', id = re.compile("itemlist_[A-Z0-9]\d{9}"))    # 撈出所有頁面上相關的 tbody 區塊
    
        print('本頁面共有', len(items), '筆資料！')
        print('** 每一頁爬取的時間間隔約 30~40 秒之間 **')

        for item in items:
    
            book = item.select("div.box_1 a img")[0]['alt']
    
            #print(book)
    
            #加到 pd.Series,(drop = True)用以重設索引值，從 0 開始
            books = books.append(pd.Series([book])).reset_index(drop = True)
    
            price = item.select("ul.list-nav.clearfix li strong")
    
            if len(price) == 1:  # 只有優惠價格
        
                # .string 取 tag<strong></strong> 中的文字內容 
                prices = prices.append(pd.Series([price[0].string])).reset_index(drop = True) 
        
            elif (len(price) == 2): #有打折數 +價格
        
                # .string 取 tag<strong></strong> 中的文字內容 
                prices = prices.append(pd.Series([price[1].string])).reset_index(drop = True)
        
            else:
        
                break  
            
        # 讓程式睡個幾秒(建議 30~60 秒或更久)再繼續爬取下一頁資料，避免頻繁抓取被台灣證券交易所封鎖 IP 拒絕存取
        time.sleep((random.uniform(30, 40))) 
        

    print('\n\n')    

    # 書籍與價格項目索引值由 1 開始
    books.index += 1

    prices.index += 1

    #print(books, '\n\n')

    #print(prices)

    #合併成 DataFrame
    df = pd.DataFrame({'書名':books, '價格': prices})

    return df

def search_books_com_tw():
    
    item_name = input('請輸入要搜尋的項目：')

    url = url_main % (item_name, cat)
    
    try:
        
        res = requests.get(url, headers = headers)  # 加上 header = headers
    
        #res.encoding = "utf-8"    # 此行必須要加，否則中文變成亂碼
    
        #res.raise_for_status()

    except Exception as err:            # err 是系統自訂的錯誤訊息

        print("博客來主網頁下載失敗:\n %s" % (err))

    else:

        #print("\n網頁下載成功：使用偽裝瀏覽器方式擷取網路資料成功！")

        #print("\n網頁內容大小 = %d 位元組" % (len(htmlfile.text)))  # 可取得網頁內容大小

        #print(res.text)   # 使用 text 屬性將取得網頁的原始碼呈現出來
    
        soup = BeautifulSoup(res.text, 'html.parser')   # 將 html格式的字串傳進 BeautifulSoup

        #print(soup)              # 直接印結果
        #print(soup.prettify())   # 如果想要呈現正常的 html 格式的話，可以多加 prettify()這個函式進來

        # 取得欲搜尋項目在網站上總頁數的內容
        page_info = soup.find('select', {'id':'page_select', 'onchange':'changePage(this)'})\
                    .find('option', {'selected': True}).text
    
        print(page_info)    
    
        total_pages = int( re.search(r'\d+', page_info).group(0) ) # 過濾出總頁數的數字內容
    
        return item_name, total_pages

if __name__ == "__main__":
    
    # 至博客來網站上執行搜尋任務
    item_name, total_pages = search_books_com_tw()
    
    # 準備好爬取書名的 Pandas Series 物件
    books = pd.Series([], dtype = object)

    # 準備好爬取價格的 Pandas Series 物件
    prices = pd.Series([], dtype = object)

    #
    df = web_crawler(item_name, total_pages, books, prices)
# Out:
# 請輸入要搜尋的項目：ubuntu
# 共 20 頁
#
# 第01頁的網頁內容大小 = 74883 位元組
# 本頁面共有 24 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第02頁的網頁內容大小 = 74158 位元組
# 本頁面共有 23 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第03頁的網頁內容大小 = 77938 位元組
# 本頁面共有 23 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第04頁的網頁內容大小 = 77121 位元組
# 本頁面共有 24 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第05頁的網頁內容大小 = 68536 位元組
# 本頁面共有 24 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第06頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第06頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第06頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第06頁的網頁內容大小 = 80184 位元組
# 本頁面共有 24 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第07頁的網頁內容大小 = 81891 位元組
# 本頁面共有 22 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第08頁的網頁內容大小 = 80667 位元組
# 本頁面共有 21 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第09頁的網頁內容大小 = 78386 位元組
# 本頁面共有 24 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第10頁的網頁內容大小 = 67623 位元組
# 本頁面共有 24 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第11頁的網頁內容大小 = 72947 位元組
# 本頁面共有 20 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第12頁的網頁內容大小 = 70272 位元組
# 本頁面共有 21 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第13頁的網頁內容大小 = 71190 位元組
# 本頁面共有 19 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第14頁的網頁內容大小 = 68100 位元組
# 本頁面共有 23 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第15頁的網頁內容大小 = 67119 位元組
# 本頁面共有 24 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第16頁的網頁內容大小 = 70493 位元組
# 本頁面共有 24 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第17頁的網頁內容大小 = 74252 位元組
# 本頁面共有 12 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第18頁的網頁內容大小 = 0 位元組
# ** 如特定頁數爬不到資料時，會延長時間間隔約 50-60 秒之間，並以無限迴圈方式重新嘗試，直到抓取該頁完整資料為止 **
#
# 第18頁的網頁內容大小 = 68079 位元組
# 本頁面共有 19 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第19頁的網頁內容大小 = 73642 位元組
# 本頁面共有 15 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **
#
# 第20頁的網頁內容大小 = 70996 位元組
# 本頁面共有 15 筆資料！
# ** 每一頁爬取的時間間隔約 30~40 秒之間 **

# %%
df
# Out:
#                                                     書名     價格
# 1                                               Ubuntu    810
# 2                                               Ubuntu   1575
# 3                                     Ubuntu 20管理入門與實作    474
# 4                                Ubuntu 系統管理與架站實務(第三版)    618
# 5    新時代 丙級電腦硬體裝修學術科研讀範本(含資訊類及技能檢定共同學科)使用Windows 10...    405
# ..                                                 ...    ...
# 421  Walk With Us and Listen: Political Reconciliat...   1498
# 422                                        God’s Dream    630
# 423            Last Orders at Harrods: An African Tale    640
# 424                          Guide to UNIX Using Linux  10898
# 425  Practical PHP and MySOL: Building Eight Dynami...   1750
#
# [425 rows x 2 columns]

# %%
df.style\
    .set_table_styles([ dict(selector = 'th',\
                             props = [('text-align', 'center'),\
                                        ('color', 'Green'), \
                                        ("font-size", "125%"),\
                                        ('background-color', '#f7f7f9')])])\
    .set_properties(**{'text-align': 'left', \
                        'background-color': 'black', \
                        'max-width': '650px',\
                        'color': 'lawngreen',\
                        'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_949f0_ th {
#           text-align: center;
#           color: Green;
#           font-size: 125%;
#           background-color: #f7f7f9;
#     }#T_949f0_row0_col0,#T_949f0_row0_col1,#T_949f0_row1_col0,#T_949f0_row1_col1,#T_949f0_row2_col0,#T_949f0_row2_col1,#T_949f0_row3_col0,#T_949f0_row3_col1,#T_949f0_row4_col0,#T_949f0_row4_col1,#T_949f0_row5_col0,#T_949f0_row5_col1,#T_949f0_row6_col0,#T_949f0_row6_col1,#T_949f0_row7_col0,#T_949f0_row7_col1,#T_949f0_row8_col0,#T_949f0_row8_col1,#T_949f0_row9_col0,#T_949f0_row9_col1,#T_949f0_row10_col0,#T_949f0_row10_col1,#T_949f0_row11_col0,#T_949f0_row11_col1,#T_949f0_row12_col0,#T_949f0_row12_col1,#T_949f0_row13_col0,#T_949f0_row13_col1,#T_949f0_row14_col0,#T_949f0_row14_col1,#T_949f0_row15_col0,#T_949f0_row15_col1,#T_949f0_row16_col0,#T_949f0_row16_col1,#T_949f0_row17_col0,#T_949f0_row17_col1,#T_949f0_row18_col0,#T_949f0_row18_col1,#T_949f0_row19_col0,#T_949f0_row19_col1,#T_949f0_row20_col0,#T_949f0_row20_col1,#T_949f0_row21_col0,#T_949f0_row21_col1,#T_949f0_row22_col0,#T_949f0_row22_col1,#T_949f0_row23_col0,#T_949f0_row23_col1,#T_949f0_row24_col0,#T_949f0_row24_col1,#T_949f0_row25_col0,#T_949f0_row25_col1,#T_949f0_row26_col0,#T_949f0_row26_col1,#T_949f0_row27_col0,#T_949f0_row27_col1,#T_949f0_row28_col0,#T_949f0_row28_col1,#T_949f0_row29_col0,#T_949f0_row29_col1,#T_949f0_row30_col0,#T_949f0_row30_col1,#T_949f0_row31_col0,#T_949f0_row31_col1,#T_949f0_row32_col0,#T_949f0_row32_col1,#T_949f0_row33_col0,#T_949f0_row33_col1,#T_949f0_row34_col0,#T_949f0_row34_col1,#T_949f0_row35_col0,#T_949f0_row35_col1,#T_949f0_row36_col0,#T_949f0_row36_col1,#T_949f0_row37_col0,#T_949f0_row37_col1,#T_949f0_row38_col0,#T_949f0_row38_col1,#T_949f0_row39_col0,#T_949f0_row39_col1,#T_949f0_row40_col0,#T_949f0_row40_col1,#T_949f0_row41_col0,#T_949f0_row41_col1,#T_949f0_row42_col0,#T_949f0_row42_col1,#T_949f0_row43_col0,#T_949f0_row43_col1,#T_949f0_row44_col0,#T_949f0_row44_col1,#T_949f0_row45_col0,#T_949f0_row45_col1,#T_949f0_row46_col0,#T_949f0_row46_col1,#T_949f0_row47_col0,#T_949f0_row47_col1,#T_949f0_row48_col0,#T_949f0_row48_col1,#T_949f0_row49_col0,#T_949f0_row49_col1,#T_949f0_row50_col0,#T_949f0_row50_col1,#T_949f0_row51_col0,#T_949f0_row51_col1,#T_949f0_row52_col0,#T_949f0_row52_col1,#T_949f0_row53_col0,#T_949f0_row53_col1,#T_949f0_row54_col0,#T_949f0_row54_col1,#T_949f0_row55_col0,#T_949f0_row55_col1,#T_949f0_row56_col0,#T_949f0_row56_col1,#T_949f0_row57_col0,#T_949f0_row57_col1,#T_949f0_row58_col0,#T_949f0_row58_col1,#T_949f0_row59_col0,#T_949f0_row59_col1,#T_949f0_row60_col0,#T_949f0_row60_col1,#T_949f0_row61_col0,#T_949f0_row61_col1,#T_949f0_row62_col0,#T_949f0_row62_col1,#T_949f0_row63_col0,#T_949f0_row63_col1,#T_949f0_row64_col0,#T_949f0_row64_col1,#T_949f0_row65_col0,#T_949f0_row65_col1,#T_949f0_row66_col0,#T_949f0_row66_col1,#T_949f0_row67_col0,#T_949f0_row67_col1,#T_949f0_row68_col0,#T_949f0_row68_col1,#T_949f0_row69_col0,#T_949f0_row69_col1,#T_949f0_row70_col0,#T_949f0_row70_col1,#T_949f0_row71_col0,#T_949f0_row71_col1,#T_949f0_row72_col0,#T_949f0_row72_col1,#T_949f0_row73_col0,#T_949f0_row73_col1,#T_949f0_row74_col0,#T_949f0_row74_col1,#T_949f0_row75_col0,#T_949f0_row75_col1,#T_949f0_row76_col0,#T_949f0_row76_col1,#T_949f0_row77_col0,#T_949f0_row77_col1,#T_949f0_row78_col0,#T_949f0_row78_col1,#T_949f0_row79_col0,#T_949f0_row79_col1,#T_949f0_row80_col0,#T_949f0_row80_col1,#T_949f0_row81_col0,#T_949f0_row81_col1,#T_949f0_row82_col0,#T_949f0_row82_col1,#T_949f0_row83_col0,#T_949f0_row83_col1,#T_949f0_row84_col0,#T_949f0_row84_col1,#T_949f0_row85_col0,#T_949f0_row85_col1,#T_949f0_row86_col0,#T_949f0_row86_col1,#T_949f0_row87_col0,#T_949f0_row87_col1,#T_949f0_row88_col0,#T_949f0_row88_col1,#T_949f0_row89_col0,#T_949f0_row89_col1,#T_949f0_row90_col0,#T_949f0_row90_col1,#T_949f0_row91_col0,#T_949f0_row91_col1,#T_949f0_row92_col0,#T_949f0_row92_col1,#T_949f0_row93_col0,#T_949f0_row93_col1,#T_949f0_row94_col0,#T_949f0_row94_col1,#T_949f0_row95_col0,#T_949f0_row95_col1,#T_949f0_row96_col0,#T_949f0_row96_col1,#T_949f0_row97_col0,#T_949f0_row97_col1,#T_949f0_row98_col0,#T_949f0_row98_col1,#T_949f0_row99_col0,#T_949f0_row99_col1,#T_949f0_row100 ...
